# %% [markdown]
# What is the probability that you will draw a dual land and a basic land card on your first hand? In MTG hands have 7 cards and the deck contains 100 cards.

# %%
import random
import pandas as pd
import seaborn as sns

# Combine all values from NonLand and Land into one list, drop NaN

# Read a CSV file named 'data.csv' into a DataFrame
df = pd.read_csv('eldrazi.csv')

drawn_items = df.sample(n=7)

# Create a dataframe of the drawn items
# drawn_df = pd.DataFrame(drawn_items, columns=["Drawn_Item"])

# drawn_df
drawn_items
# Out:
#                          Card     Type
# 23  Return of the Wildspeaker  NonLand
# 48              Vile Redeemer  NonLand
# 70          Twisted Landscape  NonLand
# 4           Eldritch Immunity  NonLand
# 7          Bismuth Mindrender  NonLand
# 22            Drowner of Hope  NonLand
# 24           Tendo Ice Bridge  NonLand

# %% [markdown]
# Out of 100 attempts you will draw a Land and a Dual land every 10 or so draws.

# %%
import random
import pandas as pd
import seaborn as sns

# Read CSV into a DataFrame
df = pd.read_csv('eldrazi.csv')

# Run 10 times
for i in range(100):
    drawn_items = df.sample(n=7)
    print(f"Draw {i+1}:")
    print(drawn_items)
    print("-" * 80)
# Out:
# Draw 1:
#                       Card     Type
# 61     Everflowing Chalice  NonLand
# 30          Oblivion Sower  NonLand
# 0   Ulalek, Fused Atrocity  NonLand
# 49       Eldrazi Displacer  NonLand
# 86   Talisman of Dominance     Land
# 26         Llanowar Wastes  NonLand
# 15     Ugin, the Ineffable  NonLand
# --------------------------------------------------------------------------------
# Draw 2:
#                        Card     Type
# 66   Talisman of Resilience  NonLand
# 100                  Forest     Land
# 32         Karplusan Forest  NonLand
# 13    Chittering Dispatcher  NonLand
# 65         Titans' Vanguard  NonLand
# 26          Llanowar Wastes  NonLand
# 72            Tectonic Edge  NonLand
# --------------------------------------------------------------------------------
# Draw 3:
#                             Card     Type
# 45                    Endbringer  NonLand
# 95           Unclaimed Territory     Land
# 15           Ugin, the Ineffable  NonLand
# 21                Ugin's Insight  NonLand
# 1   Azlask, the Swelling Scourge  NonLand
# 28                     Brushland  NonLand
# 35               Caves of Koilos  NonLand
# --------------------------------------------------------------------------------
# Draw 4:
#                             Card      Type
# 78                 Arcane Signet   NonLand
# 7             Bismuth Mindrender   NonLand
# 1   Azlask, the Swelling Scourge   NonLand
# 8             Hideous Taskmaster   NonLand
# 6             Angelic Aberration   NonLand
# 94              Path of Ancestry  DualLand
# 39             Temple of Silence   NonLand
# --------------------------------------------------------------------------------
# Draw 5:
#                             Card     Type
# 1   Azlask, the Swelling Scourge  NonLand
# 59             Snapping Voidcraw  NonLand
# 54                Eldrazi Temple  NonLand
# 42                 World Breaker  NonLand
# 49             Eldrazi Displacer  NonLand
# 84           Talisman of Impulse     Land
# 23     Return of the Wildspeaker  NonLand
# --------------------------------------------------------------------------------
# Draw 6:
#                    Card     Type
# 42        World Breaker  NonLand
# 55     Elder Deep-Fiend  NonLand
# 100              Forest     Land
# 80   Secluded Courtyard  NonLand
# 56     Bonders' Enclave  NonLand
# 10      Mutated Cultist  NonLand
# 69   Ulamog's Nullifier  NonLand
# --------------------------------------------------------------------------------
# Draw 7:
#                          Card     Type
# 90           Ulamog's Crusher     Land
# 73            Reliquary Tower  NonLand
# 83      Talisman of Curiosity     Land
# 23  Return of the Wildspeaker  NonLand
# 17        Cascading Cataracts  NonLand
# 3             Benthic Anomaly  NonLand
# 75         Artisan of Kozilek  NonLand
# --------------------------------------------------------------------------------
# Draw 8:
#                             Card     Type
# 60                 Herald's Horn  NonLand
# 97                        Island     Land
# 26               Llanowar Wastes  NonLand
# 1   Azlask, the Swelling Scourge  NonLand
# 74                      Sol Ring  NonLand
# 39             Temple of Silence  NonLand
# 83         Talisman of Curiosity     Land
# --------------------------------------------------------------------------------
# Draw 9:
#                    Card     Type
# 68         Spawning Bed  NonLand
# 18     Eldrazi Monument  NonLand
# 73      Reliquary Tower  NonLand
# 11   Eldrazi Confluence  NonLand
# 22      Drowner of Hope  NonLand
# 75   Artisan of Kozilek  NonLand
# 61  Everflowing Chalice  NonLand
# --------------------------------------------------------------------------------
# Draw 10:
#                   Card     Type
# 39   Temple of Silence  NonLand
# 67      Hedron Archive  NonLand
# 54      Eldrazi Temple  NonLand
# 11  Eldrazi Confluence  NonLand
# 62  Glaring Fleshraker  NonLand
# 80  Secluded Courtyard  NonLand
# 6   Angelic Aberration  NonLand
# --------------------------------------------------------------------------------
# Draw 11:
#                   Card     Type
# 75  Artisan of Kozilek  NonLand
# 47  Deepfathom Skulker  NonLand
# 6   Angelic Aberration  NonLand
# 78       Arcane Signet  NonLand
# 39   Temple of Silence  NonLand
# 59   Snapping Voidcraw  NonLand
# 80  Secluded Courtyard  NonLand
# --------------------------------------------------------------------------------
# Draw 12:
#                          Card     Type
# 13      Chittering Dispatcher  NonLand
# 3             Benthic Anomaly  NonLand
# 33             Yavimaya Coast  NonLand
# 72              Tectonic Edge  NonLand
# 2          Ulamog's Dreadsire  NonLand
# 23  Return of the Wildspeaker  NonLand
# 6          Angelic Aberration  NonLand
# --------------------------------------------------------------------------------
# Draw 13:
#                  Card      Type
# 97             Island      Land
# 90   Ulamog's Crusher      Land
# 9    Twins of Discord   NonLand
# 33     Yavimaya Coast   NonLand
# 77  Dreamstone Hedron   NonLand
# 85       Warping Wail  DualLand
# 57     Exotic Orchard   NonLand
# --------------------------------------------------------------------------------
# Draw 14:
#                       Card     Type
# 38        Temple of Malady  NonLand
# 59       Snapping Voidcraw  NonLand
# 80      Secluded Courtyard  NonLand
# 75      Artisan of Kozilek  NonLand
# 74                Sol Ring  NonLand
# 76             Opal Palace  NonLand
# 0   Ulalek, Fused Atrocity  NonLand
# --------------------------------------------------------------------------------
# Draw 15:
#                        Card     Type
# 41         Kozilek's Return  NonLand
# 75       Artisan of Kozilek  NonLand
# 25        Battlefield Forge  NonLand
# 40  Morophon, the Boundless  NonLand
# 61      Everflowing Chalice  NonLand
# 50             Mystic Forge  NonLand
# 72            Tectonic Edge  NonLand
# --------------------------------------------------------------------------------
# Draw 16:
#                     Card      Type
# 82                Wastes      Land
# 93   Skittering Invasion  DualLand
# 46  Corrupted Crossroads   NonLand
# 49     Eldrazi Displacer   NonLand
# 19    Sire of Stagnation   NonLand
# 8     Hideous Taskmaster   NonLand
# 56      Bonders' Enclave   NonLand
# --------------------------------------------------------------------------------
# Draw 17:
#                    Card      Type
# 93  Skittering Invasion  DualLand
# 74             Sol Ring   NonLand
# 25    Battlefield Forge   NonLand
# 82               Wastes      Land
# 85         Warping Wail  DualLand
# 52  Rishkar's Expertise   NonLand
# 21       Ugin's Insight   NonLand
# --------------------------------------------------------------------------------
# Draw 18:
#                           Card     Type
# 97                      Island     Land
# 99                    Mountain     Land
# 79   Tomb of the Spirit Dragon  NonLand
# 3              Benthic Anomaly  NonLand
# 5       Selective Obliteration  NonLand
# 53              Awakening Zone  NonLand
# 100                     Forest     Land
# --------------------------------------------------------------------------------
# Draw 19:
#                      Card      Type
# 85           Warping Wail  DualLand
# 36            Shivan Reef   NonLand
# 47     Deepfathom Skulker   NonLand
# 13  Chittering Dispatcher   NonLand
# 30         Oblivion Sower   NonLand
# 34      Sulfurous Springs   NonLand
# 97                 Island      Land
# --------------------------------------------------------------------------------
# Draw 20:
#                       Card     Type
# 60           Herald's Horn  NonLand
# 42           World Breaker  NonLand
# 67          Hedron Archive  NonLand
# 35         Caves of Koilos  NonLand
# 43      Ruins of Oran-Rief  NonLand
# 38        Temple of Malady  NonLand
# 37  Imprisoned in the Moon  NonLand
# --------------------------------------------------------------------------------
# Draw 21:
#                    Card     Type
# 80   Secluded Courtyard  NonLand
# 57       Exotic Orchard  NonLand
# 15  Ugin, the Ineffable  NonLand
# 47   Deepfathom Skulker  NonLand
# 68         Spawning Bed  NonLand
# 4     Eldritch Immunity  NonLand
# 84  Talisman of Impulse     Land
# --------------------------------------------------------------------------------
# Draw 22:
#                   Card     Type
# 92     Suffer the Past     Land
# 82              Wastes     Land
# 75  Artisan of Kozilek  NonLand
# 73     Reliquary Tower  NonLand
# 74            Sol Ring  NonLand
# 89   Ancient Stirrings     Land
# 96              Plains     Land
# --------------------------------------------------------------------------------
# Draw 23:
#                   Card     Type
# 24    Tendo Ice Bridge  NonLand
# 2   Ulamog's Dreadsire  NonLand
# 67      Hedron Archive  NonLand
# 30      Oblivion Sower  NonLand
# 42       World Breaker  NonLand
# 69  Ulamog's Nullifier  NonLand
# 77   Dreamstone Hedron  NonLand
# --------------------------------------------------------------------------------
# Draw 24:
#                  Card     Type
# 34  Sulfurous Springs  NonLand
# 36        Shivan Reef  NonLand
# 78      Arcane Signet  NonLand
# 51        All Is Dust  NonLand
# 42      World Breaker  NonLand
# 50       Mystic Forge  NonLand
# 48      Vile Redeemer  NonLand
# --------------------------------------------------------------------------------
# Draw 25:
#                             Card     Type
# 10               Mutated Cultist  NonLand
# 30                Oblivion Sower  NonLand
# 1   Azlask, the Swelling Scourge  NonLand
# 26               Llanowar Wastes  NonLand
# 0         Ulalek, Fused Atrocity  NonLand
# 19            Sire of Stagnation  NonLand
# 92               Suffer the Past     Land
# --------------------------------------------------------------------------------
# Draw 26:
#                             Card     Type
# 63         Wastescape Battlemage  NonLand
# 1   Azlask, the Swelling Scourge  NonLand
# 22               Drowner of Hope  NonLand
# 58             Forsaken Monument  NonLand
# 81              Idol of Oblivion  NonLand
# 96                        Plains     Land
# 52           Rishkar's Expertise  NonLand
# --------------------------------------------------------------------------------
# Draw 27:
#                   Card     Type
# 74            Sol Ring  NonLand
# 4    Eldritch Immunity  NonLand
# 12  Spawnbed Protector  NonLand
# 82              Wastes     Land
# 8   Hideous Taskmaster  NonLand
# 87       Command Tower     Land
# 68        Spawning Bed  NonLand
# --------------------------------------------------------------------------------
# Draw 28:
#                          Card     Type
# 15        Ugin, the Ineffable  NonLand
# 47         Deepfathom Skulker  NonLand
# 75         Artisan of Kozilek  NonLand
# 77          Dreamstone Hedron  NonLand
# 63      Wastescape Battlemage  NonLand
# 23  Return of the Wildspeaker  NonLand
# 9            Twins of Discord  NonLand
# --------------------------------------------------------------------------------
# Draw 29:
#                    Card     Type
# 81     Idol of Oblivion  NonLand
# 44     Sifter of Skulls  NonLand
# 33       Yavimaya Coast  NonLand
# 77    Dreamstone Hedron  NonLand
# 6    Angelic Aberration  NonLand
# 52  Rishkar's Expertise  NonLand
# 57       Exotic Orchard  NonLand
# --------------------------------------------------------------------------------
# Draw 30:
#                    Card      Type
# 75   Artisan of Kozilek   NonLand
# 4     Eldritch Immunity   NonLand
# 99             Mountain      Land
# 48        Vile Redeemer   NonLand
# 21       Ugin's Insight   NonLand
# 12   Spawnbed Protector   NonLand
# 93  Skittering Invasion  DualLand
# --------------------------------------------------------------------------------
# Draw 31:
#                    Card      Type
# 12   Spawnbed Protector   NonLand
# 67       Hedron Archive   NonLand
# 77    Dreamstone Hedron   NonLand
# 99             Mountain      Land
# 50         Mystic Forge   NonLand
# 82               Wastes      Land
# 93  Skittering Invasion  DualLand
# --------------------------------------------------------------------------------
# Draw 32:
#                   Card     Type
# 10     Mutated Cultist  NonLand
# 89   Ancient Stirrings     Land
# 50        Mystic Forge  NonLand
# 45          Endbringer  NonLand
# 69  Ulamog's Nullifier  NonLand
# 80  Secluded Courtyard  NonLand
# 51         All Is Dust  NonLand
# --------------------------------------------------------------------------------
# Draw 33:
#                          Card      Type
# 83      Talisman of Curiosity      Land
# 7          Bismuth Mindrender   NonLand
# 13      Chittering Dispatcher   NonLand
# 76                Opal Palace   NonLand
# 79  Tomb of the Spirit Dragon   NonLand
# 12         Spawnbed Protector   NonLand
# 91          Garruk's Uprising  DualLand
# --------------------------------------------------------------------------------
# Draw 34:
#                   Card      Type
# 55    Elder Deep-Fiend   NonLand
# 98               Swamp      Land
# 91   Garruk's Uprising  DualLand
# 88         Ash Barrens      Land
# 71  Tranquil Landscape   NonLand
# 30      Oblivion Sower   NonLand
# 32    Karplusan Forest   NonLand
# --------------------------------------------------------------------------------
# Draw 35:
#                          Card     Type
# 66     Talisman of Resilience  NonLand
# 34          Sulfurous Springs  NonLand
# 79  Tomb of the Spirit Dragon  NonLand
# 26            Llanowar Wastes  NonLand
# 15        Ugin, the Ineffable  NonLand
# 48              Vile Redeemer  NonLand
# 72              Tectonic Edge  NonLand
# --------------------------------------------------------------------------------
# Draw 36:
#                       Card     Type
# 37  Imprisoned in the Moon  NonLand
# 59       Snapping Voidcraw  NonLand
# 51             All Is Dust  NonLand
# 14      Inversion Behemoth  NonLand
# 61     Everflowing Chalice  NonLand
# 76             Opal Palace  NonLand
# 41        Kozilek's Return  NonLand
# --------------------------------------------------------------------------------
# Draw 37:
#                            Card     Type
# 0        Ulalek, Fused Atrocity  NonLand
# 39            Temple of Silence  NonLand
# 20  Shrine of the Forsaken Gods  NonLand
# 25            Battlefield Forge  NonLand
# 88                  Ash Barrens     Land
# 31               Adarkar Wastes  NonLand
# 84          Talisman of Impulse     Land
# --------------------------------------------------------------------------------
# Draw 38:
#                        Card     Type
# 35          Caves of Koilos  NonLand
# 47       Deepfathom Skulker  NonLand
# 50             Mystic Forge  NonLand
# 100                  Forest     Land
# 21           Ugin's Insight  NonLand
# 66   Talisman of Resilience  NonLand
# 95      Unclaimed Territory     Land
# --------------------------------------------------------------------------------
# Draw 39:
#                    Card     Type
# 39    Temple of Silence  NonLand
# 95  Unclaimed Territory     Land
# 67       Hedron Archive  NonLand
# 99             Mountain     Land
# 54       Eldrazi Temple  NonLand
# 69   Ulamog's Nullifier  NonLand
# 2    Ulamog's Dreadsire  NonLand
# --------------------------------------------------------------------------------
# Draw 40:
#                   Card     Type
# 77   Dreamstone Hedron  NonLand
# 71  Tranquil Landscape  NonLand
# 82              Wastes     Land
# 74            Sol Ring  NonLand
# 51         All Is Dust  NonLand
# 9     Twins of Discord  NonLand
# 8   Hideous Taskmaster  NonLand
# --------------------------------------------------------------------------------
# Draw 41:
#                       Card     Type
# 14      Inversion Behemoth  NonLand
# 89       Ancient Stirrings     Land
# 73         Reliquary Tower  NonLand
# 90        Ulamog's Crusher     Land
# 31          Adarkar Wastes  NonLand
# 37  Imprisoned in the Moon  NonLand
# 88             Ash Barrens     Land
# --------------------------------------------------------------------------------
# Draw 42:
#                          Card      Type
# 93        Skittering Invasion  DualLand
# 62         Glaring Fleshraker   NonLand
# 89          Ancient Stirrings      Land
# 78              Arcane Signet   NonLand
# 79  Tomb of the Spirit Dragon   NonLand
# 17        Cascading Cataracts   NonLand
# 97                     Island      Land
# --------------------------------------------------------------------------------
# Draw 43:
#                   Card      Type
# 47  Deepfathom Skulker   NonLand
# 14  Inversion Behemoth   NonLand
# 65    Titans' Vanguard   NonLand
# 85        Warping Wail  DualLand
# 80  Secluded Courtyard   NonLand
# 58   Forsaken Monument   NonLand
# 9     Twins of Discord   NonLand
# --------------------------------------------------------------------------------
# Draw 44:
#                       Card      Type
# 85            Warping Wail  DualLand
# 37  Imprisoned in the Moon   NonLand
# 66  Talisman of Resilience   NonLand
# 71      Tranquil Landscape   NonLand
# 15     Ugin, the Ineffable   NonLand
# 44        Sifter of Skulls   NonLand
# 56        Bonders' Enclave   NonLand
# --------------------------------------------------------------------------------
# Draw 45:
#                   Card      Type
# 30      Oblivion Sower   NonLand
# 85        Warping Wail  DualLand
# 96              Plains      Land
# 4    Eldritch Immunity   NonLand
# 78       Arcane Signet   NonLand
# 12  Spawnbed Protector   NonLand
# 19  Sire of Stagnation   NonLand
# --------------------------------------------------------------------------------
# Draw 46:
#                      Card     Type
# 63  Wastescape Battlemage  NonLand
# 13  Chittering Dispatcher  NonLand
# 18       Eldrazi Monument  NonLand
# 83  Talisman of Curiosity     Land
# 29      Underground River  NonLand
# 57         Exotic Orchard  NonLand
# 31         Adarkar Wastes  NonLand
# --------------------------------------------------------------------------------
# Draw 47:
#                       Card     Type
# 33          Yavimaya Coast  NonLand
# 38        Temple of Malady  NonLand
# 75      Artisan of Kozilek  NonLand
# 9         Twins of Discord  NonLand
# 29       Underground River  NonLand
# 66  Talisman of Resilience  NonLand
# 11      Eldrazi Confluence  NonLand
# --------------------------------------------------------------------------------
# Draw 48:
#                  Card     Type
# 60      Herald's Horn  NonLand
# 59  Snapping Voidcraw  NonLand
# 35    Caves of Koilos  NonLand
# 34  Sulfurous Springs  NonLand
# 90   Ulamog's Crusher     Land
# 10    Mutated Cultist  NonLand
# 39  Temple of Silence  NonLand
# --------------------------------------------------------------------------------
# Draw 49:
#                       Card     Type
# 58       Forsaken Monument  NonLand
# 0   Ulalek, Fused Atrocity  NonLand
# 27         Llanowar Wastes  NonLand
# 10         Mutated Cultist  NonLand
# 2       Ulamog's Dreadsire  NonLand
# 71      Tranquil Landscape  NonLand
# 6       Angelic Aberration  NonLand
# --------------------------------------------------------------------------------
# Draw 50:
#                    Card     Type
# 69   Ulamog's Nullifier  NonLand
# 27      Llanowar Wastes  NonLand
# 89    Ancient Stirrings     Land
# 32     Karplusan Forest  NonLand
# 48        Vile Redeemer  NonLand
# 100              Forest     Land
# 58    Forsaken Monument  NonLand
# --------------------------------------------------------------------------------
# Draw 51:
#                   Card     Type
# 25   Battlefield Forge  NonLand
# 81    Idol of Oblivion  NonLand
# 55    Elder Deep-Fiend  NonLand
# 90    Ulamog's Crusher     Land
# 43  Ruins of Oran-Rief  NonLand
# 19  Sire of Stagnation  NonLand
# 32    Karplusan Forest  NonLand
# --------------------------------------------------------------------------------
# Draw 52:
#                     Card      Type
# 3        Benthic Anomaly   NonLand
# 78         Arcane Signet   NonLand
# 46  Corrupted Crossroads   NonLand
# 94      Path of Ancestry  DualLand
# 22       Drowner of Hope   NonLand
# 31        Adarkar Wastes   NonLand
# 15   Ugin, the Ineffable   NonLand
# --------------------------------------------------------------------------------
# Draw 53:
#                      Card      Type
# 44       Sifter of Skulls   NonLand
# 59      Snapping Voidcraw   NonLand
# 85           Warping Wail  DualLand
# 86  Talisman of Dominance      Land
# 43     Ruins of Oran-Rief   NonLand
# 73        Reliquary Tower   NonLand
# 31         Adarkar Wastes   NonLand
# --------------------------------------------------------------------------------
# Draw 54:
#                        Card     Type
# 14       Inversion Behemoth  NonLand
# 70        Twisted Landscape  NonLand
# 92          Suffer the Past     Land
# 15      Ugin, the Ineffable  NonLand
# 40  Morophon, the Boundless  NonLand
# 86    Talisman of Dominance     Land
# 4         Eldritch Immunity  NonLand
# --------------------------------------------------------------------------------
# Draw 55:
#                          Card      Type
# 85               Warping Wail  DualLand
# 75         Artisan of Kozilek   NonLand
# 38           Temple of Malady   NonLand
# 8          Hideous Taskmaster   NonLand
# 12         Spawnbed Protector   NonLand
# 48              Vile Redeemer   NonLand
# 23  Return of the Wildspeaker   NonLand
# --------------------------------------------------------------------------------
# Draw 56:
#                    Card      Type
# 78        Arcane Signet   NonLand
# 75   Artisan of Kozilek   NonLand
# 4     Eldritch Immunity   NonLand
# 52  Rishkar's Expertise   NonLand
# 93  Skittering Invasion  DualLand
# 88          Ash Barrens      Land
# 73      Reliquary Tower   NonLand
# --------------------------------------------------------------------------------
# Draw 57:
#                          Card     Type
# 9            Twins of Discord  NonLand
# 51                All Is Dust  NonLand
# 79  Tomb of the Spirit Dragon  NonLand
# 97                     Island     Land
# 3             Benthic Anomaly  NonLand
# 90           Ulamog's Crusher     Land
# 7          Bismuth Mindrender  NonLand
# --------------------------------------------------------------------------------
# Draw 58:
#                      Card      Type
# 26        Llanowar Wastes   NonLand
# 89      Ancient Stirrings      Land
# 85           Warping Wail  DualLand
# 91      Garruk's Uprising  DualLand
# 50           Mystic Forge   NonLand
# 49      Eldrazi Displacer   NonLand
# 86  Talisman of Dominance      Land
# --------------------------------------------------------------------------------
# Draw 59:
#                            Card     Type
# 82                       Wastes     Land
# 24             Tendo Ice Bridge  NonLand
# 50                 Mystic Forge  NonLand
# 78                Arcane Signet  NonLand
# 14           Inversion Behemoth  NonLand
# 20  Shrine of the Forsaken Gods  NonLand
# 4             Eldritch Immunity  NonLand
# --------------------------------------------------------------------------------
# Draw 60:
#                   Card     Type
# 28           Brushland  NonLand
# 71  Tranquil Landscape  NonLand
# 92     Suffer the Past     Land
# 6   Angelic Aberration  NonLand
# 99            Mountain     Land
# 73     Reliquary Tower  NonLand
# 62  Glaring Fleshraker  NonLand
# --------------------------------------------------------------------------------
# Draw 61:
#                            Card     Type
# 0        Ulalek, Fused Atrocity  NonLand
# 57               Exotic Orchard  NonLand
# 20  Shrine of the Forsaken Gods  NonLand
# 41             Kozilek's Return  NonLand
# 11           Eldrazi Confluence  NonLand
# 51                  All Is Dust  NonLand
# 86        Talisman of Dominance     Land
# --------------------------------------------------------------------------------
# Draw 62:
#                      Card     Type
# 38       Temple of Malady  NonLand
# 62     Glaring Fleshraker  NonLand
# 75     Artisan of Kozilek  NonLand
# 18       Eldrazi Monument  NonLand
# 78          Arcane Signet  NonLand
# 65       Titans' Vanguard  NonLand
# 13  Chittering Dispatcher  NonLand
# --------------------------------------------------------------------------------
# Draw 63:
#                          Card     Type
# 64                  Crib Swap  NonLand
# 2          Ulamog's Dreadsire  NonLand
# 86      Talisman of Dominance     Land
# 56           Bonders' Enclave  NonLand
# 44           Sifter of Skulls  NonLand
# 23  Return of the Wildspeaker  NonLand
# 33             Yavimaya Coast  NonLand
# --------------------------------------------------------------------------------
# Draw 64:
#                    Card      Type
# 93  Skittering Invasion  DualLand
# 72        Tectonic Edge   NonLand
# 27      Llanowar Wastes   NonLand
# 82               Wastes      Land
# 88          Ash Barrens      Land
# 29    Underground River   NonLand
# 45           Endbringer   NonLand
# --------------------------------------------------------------------------------
# Draw 65:
#                  Card     Type
# 65   Titans' Vanguard  NonLand
# 36        Shivan Reef  NonLand
# 30     Oblivion Sower  NonLand
# 10    Mutated Cultist  NonLand
# 57     Exotic Orchard  NonLand
# 82             Wastes     Land
# 59  Snapping Voidcraw  NonLand
# --------------------------------------------------------------------------------
# Draw 66:
#                        Card     Type
# 48            Vile Redeemer  NonLand
# 87            Command Tower     Land
# 40  Morophon, the Boundless  NonLand
# 27          Llanowar Wastes  NonLand
# 42            World Breaker  NonLand
# 36              Shivan Reef  NonLand
# 45               Endbringer  NonLand
# --------------------------------------------------------------------------------
# Draw 67:
#                 Card      Type
# 31    Adarkar Wastes   NonLand
# 26   Llanowar Wastes   NonLand
# 74          Sol Ring   NonLand
# 44  Sifter of Skulls   NonLand
# 81  Idol of Oblivion   NonLand
# 21    Ugin's Insight   NonLand
# 94  Path of Ancestry  DualLand
# --------------------------------------------------------------------------------
# Draw 68:
#                       Card     Type
# 43      Ruins of Oran-Rief  NonLand
# 95     Unclaimed Territory     Land
# 83   Talisman of Curiosity     Land
# 28               Brushland  NonLand
# 37  Imprisoned in the Moon  NonLand
# 96                  Plains     Land
# 90        Ulamog's Crusher     Land
# --------------------------------------------------------------------------------
# Draw 69:
#                    Card      Type
# 51          All Is Dust   NonLand
# 81     Idol of Oblivion   NonLand
# 57       Exotic Orchard   NonLand
# 69   Ulamog's Nullifier   NonLand
# 93  Skittering Invasion  DualLand
# 43   Ruins of Oran-Rief   NonLand
# 92      Suffer the Past      Land
# --------------------------------------------------------------------------------
# Draw 70:
#                        Card     Type
# 22          Drowner of Hope  NonLand
# 98                    Swamp     Land
# 19       Sire of Stagnation  NonLand
# 40  Morophon, the Boundless  NonLand
# 59        Snapping Voidcraw  NonLand
# 66   Talisman of Resilience  NonLand
# 17      Cascading Cataracts  NonLand
# --------------------------------------------------------------------------------
# Draw 71:
#                       Card     Type
# 95     Unclaimed Territory     Land
# 0   Ulalek, Fused Atrocity  NonLand
# 68            Spawning Bed  NonLand
# 34       Sulfurous Springs  NonLand
# 69      Ulamog's Nullifier  NonLand
# 5   Selective Obliteration  NonLand
# 42           World Breaker  NonLand
# --------------------------------------------------------------------------------
# Draw 72:
#                          Card     Type
# 80         Secluded Courtyard  NonLand
# 38           Temple of Malady  NonLand
# 23  Return of the Wildspeaker  NonLand
# 26            Llanowar Wastes  NonLand
# 34          Sulfurous Springs  NonLand
# 29          Underground River  NonLand
# 65           Titans' Vanguard  NonLand
# --------------------------------------------------------------------------------
# Draw 73:
#                       Card     Type
# 21          Ugin's Insight  NonLand
# 14      Inversion Behemoth  NonLand
# 63   Wastescape Battlemage  NonLand
# 66  Talisman of Resilience  NonLand
# 25       Battlefield Forge  NonLand
# 58       Forsaken Monument  NonLand
# 29       Underground River  NonLand
# --------------------------------------------------------------------------------
# Draw 74:
#                           Card     Type
# 49           Eldrazi Displacer  NonLand
# 79   Tomb of the Spirit Dragon  NonLand
# 29           Underground River  NonLand
# 16        Eldrazi Conscription  NonLand
# 74                    Sol Ring  NonLand
# 75          Artisan of Kozilek  NonLand
# 100                     Forest     Land
# --------------------------------------------------------------------------------
# Draw 75:
#                   Card     Type
# 74            Sol Ring  NonLand
# 41    Kozilek's Return  NonLand
# 75  Artisan of Kozilek  NonLand
# 28           Brushland  NonLand
# 77   Dreamstone Hedron  NonLand
# 55    Elder Deep-Fiend  NonLand
# 72       Tectonic Edge  NonLand
# --------------------------------------------------------------------------------
# Draw 76:
#                       Card     Type
# 51             All Is Dust  NonLand
# 98                   Swamp     Land
# 21          Ugin's Insight  NonLand
# 5   Selective Obliteration  NonLand
# 30          Oblivion Sower  NonLand
# 38        Temple of Malady  NonLand
# 72           Tectonic Edge  NonLand
# --------------------------------------------------------------------------------
# Draw 77:
#                          Card      Type
# 79  Tomb of the Spirit Dragon   NonLand
# 57             Exotic Orchard   NonLand
# 91          Garruk's Uprising  DualLand
# 41           Kozilek's Return   NonLand
# 69         Ulamog's Nullifier   NonLand
# 90           Ulamog's Crusher      Land
# 38           Temple of Malady   NonLand
# --------------------------------------------------------------------------------
# Draw 78:
#                   Card      Type
# 94    Path of Ancestry  DualLand
# 73     Reliquary Tower   NonLand
# 71  Tranquil Landscape   NonLand
# 69  Ulamog's Nullifier   NonLand
# 18    Eldrazi Monument   NonLand
# 57      Exotic Orchard   NonLand
# 10     Mutated Cultist   NonLand
# --------------------------------------------------------------------------------
# Draw 79:
#                   Card     Type
# 60       Herald's Horn  NonLand
# 19  Sire of Stagnation  NonLand
# 39   Temple of Silence  NonLand
# 7   Bismuth Mindrender  NonLand
# 89   Ancient Stirrings     Land
# 44    Sifter of Skulls  NonLand
# 27     Llanowar Wastes  NonLand
# --------------------------------------------------------------------------------
# Draw 80:
#                          Card     Type
# 29          Underground River  NonLand
# 83      Talisman of Curiosity     Land
# 64                  Crib Swap  NonLand
# 97                     Island     Land
# 86      Talisman of Dominance     Land
# 13      Chittering Dispatcher  NonLand
# 79  Tomb of the Spirit Dragon  NonLand
# --------------------------------------------------------------------------------
# Draw 81:
#                  Card     Type
# 21     Ugin's Insight  NonLand
# 38   Temple of Malady  NonLand
# 88        Ash Barrens     Land
# 49  Eldrazi Displacer  NonLand
# 78      Arcane Signet  NonLand
# 72      Tectonic Edge  NonLand
# 99           Mountain     Land
# --------------------------------------------------------------------------------
# Draw 82:
#                      Card     Type
# 19     Sire of Stagnation  NonLand
# 13  Chittering Dispatcher  NonLand
# 69     Ulamog's Nullifier  NonLand
# 56       Bonders' Enclave  NonLand
# 17    Cascading Cataracts  NonLand
# 72          Tectonic Edge  NonLand
# 96                 Plains     Land
# --------------------------------------------------------------------------------
# Draw 83:
#                       Card     Type
# 55        Elder Deep-Fiend  NonLand
# 33          Yavimaya Coast  NonLand
# 9         Twins of Discord  NonLand
# 0   Ulalek, Fused Atrocity  NonLand
# 32        Karplusan Forest  NonLand
# 5   Selective Obliteration  NonLand
# 17     Cascading Cataracts  NonLand
# --------------------------------------------------------------------------------
# Draw 84:
#                      Card     Type
# 39      Temple of Silence  NonLand
# 6      Angelic Aberration  NonLand
# 32       Karplusan Forest  NonLand
# 83  Talisman of Curiosity     Land
# 18       Eldrazi Monument  NonLand
# 29      Underground River  NonLand
# 90       Ulamog's Crusher     Land
# --------------------------------------------------------------------------------
# Draw 85:
#                    Card     Type
# 59    Snapping Voidcraw  NonLand
# 9      Twins of Discord  NonLand
# 52  Rishkar's Expertise  NonLand
# 62   Glaring Fleshraker  NonLand
# 76          Opal Palace  NonLand
# 22      Drowner of Hope  NonLand
# 6    Angelic Aberration  NonLand
# --------------------------------------------------------------------------------
# Draw 86:
#                        Card     Type
# 40  Morophon, the Boundless  NonLand
# 52      Rishkar's Expertise  NonLand
# 0    Ulalek, Fused Atrocity  NonLand
# 54           Eldrazi Temple  NonLand
# 74                 Sol Ring  NonLand
# 26          Llanowar Wastes  NonLand
# 24         Tendo Ice Bridge  NonLand
# --------------------------------------------------------------------------------
# Draw 87:
#                    Card     Type
# 43   Ruins of Oran-Rief  NonLand
# 18     Eldrazi Monument  NonLand
# 99             Mountain     Land
# 77    Dreamstone Hedron  NonLand
# 82               Wastes     Land
# 84  Talisman of Impulse     Land
# 9      Twins of Discord  NonLand
# --------------------------------------------------------------------------------
# Draw 88:
#                            Card      Type
# 22              Drowner of Hope   NonLand
# 20  Shrine of the Forsaken Gods   NonLand
# 84          Talisman of Impulse      Land
# 58            Forsaken Monument   NonLand
# 75           Artisan of Kozilek   NonLand
# 86        Talisman of Dominance      Land
# 94             Path of Ancestry  DualLand
# --------------------------------------------------------------------------------
# Draw 89:
#                             Card      Type
# 81              Idol of Oblivion   NonLand
# 1   Azlask, the Swelling Scourge   NonLand
# 72                 Tectonic Edge   NonLand
# 91             Garruk's Uprising  DualLand
# 32              Karplusan Forest   NonLand
# 33                Yavimaya Coast   NonLand
# 4              Eldritch Immunity   NonLand
# --------------------------------------------------------------------------------
# Draw 90:
#                    Card      Type
# 87        Command Tower      Land
# 95  Unclaimed Territory      Land
# 28            Brushland   NonLand
# 59    Snapping Voidcraw   NonLand
# 12   Spawnbed Protector   NonLand
# 25    Battlefield Forge   NonLand
# 91    Garruk's Uprising  DualLand
# --------------------------------------------------------------------------------
# Draw 91:
#                   Card      Type
# 60       Herald's Horn   NonLand
# 19  Sire of Stagnation   NonLand
# 87       Command Tower      Land
# 85        Warping Wail  DualLand
# 18    Eldrazi Monument   NonLand
# 64           Crib Swap   NonLand
# 76         Opal Palace   NonLand
# --------------------------------------------------------------------------------
# Draw 92:
#                       Card     Type
# 13   Chittering Dispatcher  NonLand
# 21          Ugin's Insight  NonLand
# 77       Dreamstone Hedron  NonLand
# 65        Titans' Vanguard  NonLand
# 49       Eldrazi Displacer  NonLand
# 66  Talisman of Resilience  NonLand
# 90        Ulamog's Crusher     Land
# --------------------------------------------------------------------------------
# Draw 93:
#                   Card     Type
# 76         Opal Palace  NonLand
# 97              Island     Land
# 80  Secluded Courtyard  NonLand
# 87       Command Tower     Land
# 39   Temple of Silence  NonLand
# 49   Eldrazi Displacer  NonLand
# 60       Herald's Horn  NonLand
# --------------------------------------------------------------------------------
# Draw 94:
#                            Card      Type
# 94             Path of Ancestry  DualLand
# 6            Angelic Aberration   NonLand
# 82                       Wastes      Land
# 59            Snapping Voidcraw   NonLand
# 20  Shrine of the Forsaken Gods   NonLand
# 27              Llanowar Wastes   NonLand
# 32             Karplusan Forest   NonLand
# --------------------------------------------------------------------------------
# Draw 95:
#                    Card     Type
# 92      Suffer the Past     Land
# 44     Sifter of Skulls  NonLand
# 62   Glaring Fleshraker  NonLand
# 30       Oblivion Sower  NonLand
# 32     Karplusan Forest  NonLand
# 95  Unclaimed Territory     Land
# 72        Tectonic Edge  NonLand
# --------------------------------------------------------------------------------
# Draw 96:
#                   Card     Type
# 7   Bismuth Mindrender  NonLand
# 36         Shivan Reef  NonLand
# 26     Llanowar Wastes  NonLand
# 78       Arcane Signet  NonLand
# 50        Mystic Forge  NonLand
# 80  Secluded Courtyard  NonLand
# 89   Ancient Stirrings     Land
# --------------------------------------------------------------------------------
# Draw 97:
#                     Card     Type
# 46  Corrupted Crossroads  NonLand
# 60         Herald's Horn  NonLand
# 53        Awakening Zone  NonLand
# 87         Command Tower     Land
# 29     Underground River  NonLand
# 26       Llanowar Wastes  NonLand
# 78         Arcane Signet  NonLand
# --------------------------------------------------------------------------------
# Draw 98:
#                      Card     Type
# 43     Ruins of Oran-Rief  NonLand
# 61    Everflowing Chalice  NonLand
# 86  Talisman of Dominance     Land
# 68           Spawning Bed  NonLand
# 71     Tranquil Landscape  NonLand
# 27        Llanowar Wastes  NonLand
# 52    Rishkar's Expertise  NonLand
# --------------------------------------------------------------------------------
# Draw 99:
#                             Card     Type
# 36                   Shivan Reef  NonLand
# 82                        Wastes     Land
# 9               Twins of Discord  NonLand
# 90              Ulamog's Crusher     Land
# 10               Mutated Cultist  NonLand
# 98                         Swamp     Land
# 1   Azlask, the Swelling Scourge  NonLand
# --------------------------------------------------------------------------------
# Draw 100:
#                    Card     Type
# 48        Vile Redeemer  NonLand
# 71   Tranquil Landscape  NonLand
# 95  Unclaimed Territory     Land
# 72        Tectonic Edge  NonLand
# 44     Sifter of Skulls  NonLand
# 39    Temple of Silence  NonLand
# 92      Suffer the Past     Land
# --------------------------------------------------------------------------------
